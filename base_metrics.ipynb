# %%
# Import necessary libraries
import pandas as pd
from IPython.display import display, HTML
import re

# Define the LaTeX file path
latex_file = 'base_metrics.tex'

# Read the LaTeX file
with open(latex_file, 'r') as file:
    latex_content = file.read()

# Extract the table content from the LaTeX file
start_marker = '\\begin{tabular}'
end_marker = '\\end{tabular}'

start_idx = latex_content.find(start_marker)
end_idx = latex_content.find(end_marker) + len(end_marker)

if start_idx != -1 and end_idx != -1:
    table_content = latex_content[start_idx:end_idx]
else:
    table_content = "Table not found in the LaTeX file."

# Parse the table content
table_rows = table_content.split('\\\\')
parsed_data = []
for row in table_rows:
    # Remove LaTeX commands and trim whitespace
    cleaned_row = re.sub(r'\\[a-zA-Z]+', '', row).strip()
    if cleaned_row:
        parsed_data.append([cell.strip() for cell in cleaned_row.split('&')])

# Create a pandas DataFrame
columns = parsed_data[1]
data = parsed_data[2:-1]
df = pd.DataFrame(data, columns=columns)

# Display the DataFrame as an HTML table
display(HTML(df.to_html(index=False, escape=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>metric name</th>
#       <th>Number of axioms</th>
#       <th>Number of logical axioms</th>
#       <th>Number of classes</th>
#       <th>Number of object properties</th>
#       <th>Number of datatype properties</th>
#       <th>Number of annotation assertions</th>
#       <th>DL expressivity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>AMONTOLOGY</td>
#       <td>130</td>
#       <td>125</td>
#       <td>85</td>
#       <td>5</td>
#       <td>0</td>
#       <td>3</td>
#       <td>ALE</td>
#     </tr>
#     <tr>
#       <td>BWMD-DOMAIN</td>
#       <td>1800</td>
#       <td>424</td>
#       <td>459</td>
#       <td>0</td>
#       <td>0</td>
#       <td>917</td>
#       <td>AL</td>
#     </tr>
#     <tr>
#       <td>BWMD-MID</td>
#       <td>1546</td>
#       <td>399</td>
#       <td>336</td>
#       <td>27</td>
#       <td>12</td>
#       <td>771</td>
#       <td>ALCHI(D)</td>
#     </tr>
#     <tr>
#       <td>CHAMEO</td>
#       <td>491</td>
#       <td>156</td>
#       <td>74</td>
#       <td>44</td>
#       <td>2</td>
#       <td>234</td>
#       <td>ALCH(D)</td>
#     </tr>
#     <tr>
#       <td>CIF-core</td>
#       <td>321</td>
#       <td>87</td>
#       <td>31</td>
#       <td>1</td>
#       <td>1</td>
#       <td>176</td>
#       <td>AL(D)</td>
#     </tr>
#     <tr>
#       <td>DEB</td>
#       <td>2135</td>
#       <td>1110</td>
#       <td>601</td>
#       <td>12</td>
#       <td>109</td>
#       <td>296</td>
#       <td>ALH(D)</td>
#     </tr>
#     <tr>
#       <td>DISO</td>
#       <td>373</td>
#       <td>135</td>
#       <td>38</td>
#       <td>33</td>
#       <td>12</td>
#       <td>147</td>
#       <td>ALCHIQ(D)</td>
#     </tr>
#     <tr>
#       <td>EMMO</td>
#       <td>8224</td>
#       <td>2319</td>
#       <td>1191</td>
#       <td>107</td>
#       <td>10</td>
#       <td>4541</td>
#       <td>ALCROIQ(D)</td>
#     </tr>
#     <tr>
#       <td>EMMO BVC</td>
#       <td>568</td>
#       <td>276</td>
#       <td>182</td>
#       <td>11</td>
#       <td>0</td>
#       <td>131</td>
#       <td>ALCH</td>
#     </tr>
#     <tr>
#       <td>EMMO BattINFO</td>
#       <td>442</td>
#       <td>143</td>
#       <td>137</td>
#       <td>10</td>
#       <td>0</td>
#       <td>203</td>
#       <td>ALEI</td>
#     </tr>
#     <tr>
#       <td>EMMO Datamodel</td>
#       <td>89</td>
#       <td>28</td>
#       <td>11</td>
#       <td>5</td>
#       <td>5</td>
#       <td>34</td>
#       <td>ALCHQ(D)</td>
#     </tr>
#     <tr>
#       <td>EMMO atomistic</td>
#       <td>64</td>
#       <td>19</td>
#       <td>18</td>
#       <td>3</td>
#       <td>1</td>
#       <td>34</td>
#       <td>ALEH(D)</td>
#     </tr>
#     <tr>
#       <td>EMMO crystallography</td>
#       <td>357</td>
#       <td>106</td>
#       <td>61</td>
#       <td>5</td>
#       <td>1</td>
#       <td>175</td>
#       <td>ALCIQ(D)</td>
#     </tr>
#     <tr>
#       <td>EMMO mappings</td>
#       <td>73</td>
#       <td>27</td>
#       <td>9</td>
#       <td>5</td>
#       <td>3</td>
#       <td>28</td>
#       <td>ALEHQ(D)</td>
#     </tr>
#     <tr>
#       <td>EMMO mechanical testing</td>
#       <td>1740</td>
#       <td>725</td>
#       <td>393</td>
#       <td>13</td>
#       <td>6</td>
#       <td>657</td>
#       <td>ALCHIQ(D)</td>
#     </tr>
#     <tr>
#       <td>EMMO microstructure</td>
#       <td>183</td>
#       <td>80</td>
#       <td>61</td>
#       <td>2</td>
#       <td>0</td>
#       <td>60</td>
#       <td>ALE</td>
#     </tr>
#     <tr>
#       <td>GPO</td>
#       <td>6249</td>
#       <td>2640</td>
#       <td>963</td>
#       <td>86</td>
#       <td>5</td>
#       <td>2532</td>
#       <td>SROIQ(D)</td>
#     </tr>
#     <tr>
#       <td>LPBFO</td>
#       <td>663</td>
#       <td>151</td>
#       <td>179</td>
#       <td>2</td>
#       <td>0</td>
#       <td>346</td>
#       <td>ALCH</td>
#     </tr>
#     <tr>
#       <td>MAMBO</td>
#       <td>632</td>
#       <td>400</td>
#       <td>57</td>
#       <td>35</td>
#       <td>63</td>
#       <td>57</td>
#       <td>SHIQ(D)</td>
#     </tr>
#     <tr>
#       <td>MDO</td>
#       <td>457</td>
#       <td>168</td>
#       <td>37</td>
#       <td>32</td>
#       <td>32</td>
#       <td>176</td>
#       <td>ALCQ(D)</td>
#     </tr>
#     <tr>
#       <td>MOL BRINELL</td>
#       <td>16349</td>
#       <td>12818</td>
#       <td>37</td>
#       <td>17</td>
#       <td>4</td>
#       <td>191</td>
#       <td>AL(D)</td>
#     </tr>
#     <tr>
#       <td>MOL TENSILE</td>
#       <td>354</td>
#       <td>127</td>
#       <td>35</td>
#       <td>61</td>
#       <td>7</td>
#       <td>120</td>
#       <td>ALCHF(D)</td>
#     </tr>
#     <tr>
#       <td>MSEO</td>
#       <td>890</td>
#       <td>126</td>
#       <td>150</td>
#       <td>2</td>
#       <td>0</td>
#       <td>618</td>
#       <td>ALH</td>
#     </tr>
#     <tr>
#       <td>MatOnto</td>
#       <td>5235</td>
#       <td>2320</td>
#       <td>848</td>
#       <td>83</td>
#       <td>13</td>
#       <td>1841</td>
#       <td>SHOIQ(D)</td>
#     </tr>
#     <tr>
#       <td>NPO</td>
#       <td>28924</td>
#       <td>15560</td>
#       <td>1906</td>
#       <td>65</td>
#       <td>22</td>
#       <td>11343</td>
#       <td>SHIN(D)</td>
#     </tr>
#     <tr>
#       <td>NanoMine</td>
#       <td>815</td>
#       <td>229</td>
#       <td>172</td>
#       <td>1</td>
#       <td>0</td>
#       <td>429</td>
#       <td>ALEO</td>
#     </tr>
#     <tr>
#       <td>OEO</td>
#       <td>14788</td>
#       <td>3474</td>
#       <td>1445</td>
#       <td>122</td>
#       <td>1</td>
#       <td>9388</td>
#       <td>SROIQ(D)</td>
#     </tr>
#     <tr>
#       <td>PMDCO</td>
#       <td>2154</td>
#       <td>384</td>
#       <td>264</td>
#       <td>36</td>
#       <td>9</td>
#       <td>1454</td>
#       <td>ALCHIF(D)</td>
#     </tr>
#     <tr>
#       <td>SAREF</td>
#       <td>631</td>
#       <td>226</td>
#       <td>81</td>
#       <td>35</td>
#       <td>5</td>
#       <td>264</td>
#       <td>ALCIQ(D)</td>
#     </tr>
#     <tr>
#       <td>SEMMD</td>
#       <td>14827</td>
#       <td>8723</td>
#       <td>689</td>
#       <td>108</td>
#       <td>42</td>
#       <td>5238</td>
#       <td>SROIN(D)</td>
#     </tr>
#     <tr>
#       <td>SP</td>
#       <td>2999</td>
#       <td>724</td>
#       <td>399</td>
#       <td>43</td>
#       <td>0</td>
#       <td>1781</td>
#       <td>SHI</td>
#     </tr>
#     <tr>
#       <td>SSN</td>
#       <td>313</td>
#       <td>12</td>
#       <td>16</td>
#       <td>21</td>
#       <td>2</td>
#       <td>248</td>
#       <td>ALI(D)</td>
#     </tr>
#     <tr>
#       <td>bmo</td>
#       <td>362</td>
#       <td>210</td>
#       <td>26</td>
#       <td>56</td>
#       <td>7</td>
#       <td>44</td>
#       <td>ALCRI(D)</td>
#     </tr>
#     <tr>
#       <td>enanomapper</td>
#       <td>2809</td>
#       <td>727</td>
#       <td>772</td>
#       <td>2</td>
#       <td>0</td>
#       <td>1341</td>
#       <td>ALE</td>
#     </tr>
#     <tr>
#       <td>mat</td>
#       <td>549</td>
#       <td>180</td>
#       <td>140</td>
#       <td>13</td>
#       <td>8</td>
#       <td>202</td>
#       <td>ALQ(D)</td>
#     </tr>
#     <tr>
#       <td>matinfo</td>
#       <td>58</td>
#       <td>30</td>
#       <td>10</td>
#       <td>8</td>
#       <td>13</td>
#       <td>1</td>
#       <td>AL(D)</td>
#     </tr>
#     <tr>
#       <td>mvc</td>
#       <td>154</td>
#       <td>50</td>
#       <td>28</td>
#       <td>12</td>
#       <td>3</td>
#       <td>75</td>
#       <td>ALI(D)</td>
#     </tr>
#     <tr>
#       <td>mwo</td>
#       <td>1122</td>
#       <td>287</td>
#       <td>116</td>
#       <td>74</td>
#       <td>30</td>
#       <td>561</td>
#       <td>ALCHIF(D)</td>
#     </tr>
#     <tr>
#       <td>periodictable</td>
#       <td>1756</td>
#       <td>1735</td>
#       <td>7</td>
#       <td>6</td>
#       <td>7</td>
#       <td>2</td>
#       <td>ALUON(D)</td>
#     </tr>
#     <tr>
#       <td>ssos</td>
#       <td>244</td>
#       <td>89</td>
#       <td>27</td>
#       <td>19</td>
#       <td>21</td>
#       <td>79</td>
#       <td>SHI(D)</td>
#     </tr>
#     <tr>
#       <td>vimmp</td>
#       <td>11863</td>
#       <td>7252</td>
#       <td>1082</td>
#       <td>580</td>
#       <td>191</td>
#       <td>1848</td>
#       <td>SROIQ(D)</td>
#     </tr>
#   </tbody>
# </table>
