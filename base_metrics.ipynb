# %%
# Import necessary libraries
import pandas as pd
from IPython.display import display, HTML
import re

# Define the LaTeX file path
latex_file = 'base_metrics.tex'

# Read the LaTeX file
with open(latex_file, 'r') as file:
    latex_content = file.read()

# Extract the table content from the LaTeX file
start_marker = '\\begin{tabular}'
end_marker = '\\end{tabular}'

start_idx = latex_content.find(start_marker)
end_idx = latex_content.find(end_marker) + len(end_marker)

if start_idx != -1 and end_idx != -1:
    table_content = latex_content[start_idx:end_idx]
else:
    table_content = "Table not found in the LaTeX file."

# Parse the table content
table_rows = table_content.split('\\\\')
parsed_data = []
for row in table_rows:
    # Remove LaTeX commands and trim whitespace
    cleaned_row = re.sub(r'\\[a-zA-Z]+', '', row).strip()
    if cleaned_row:
        parsed_data.append([cell.strip() for cell in cleaned_row.split('&')])

# Create a pandas DataFrame
columns = parsed_data[1]
data = parsed_data[2:-1]
df = pd.DataFrame(data, columns=columns)

# Display the DataFrame as an HTML table
display(HTML(df.to_html(index=False, escape=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>metric name</th>
#       <th>\# axioms</th>
#       <th>\# logical axioms</th>
#       <th>\# classes</th>
#       <th>\# object properties</th>
#       <th>\# datatype properties</th>
#       <th>\# annotation assertions</th>
#       <th>DL expressivity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>AMONTOLOGY</td>
#       <td>130</td>
#       <td>125</td>
#       <td>85</td>
#       <td>5</td>
#       <td>0</td>
#       <td>3</td>
#       <td>ALE</td>
#     </tr>
#     <tr>
#       <td>ASMO</td>
#       <td>519</td>
#       <td>85</td>
#       <td>36</td>
#       <td>18</td>
#       <td>4</td>
#       <td>327</td>
#       <td>ALCHI(D)</td>
#     </tr>
#     <tr>
#       <td>BWMD-DOMAIN</td>
#       <td>1800</td>
#       <td>424</td>
#       <td>459</td>
#       <td>0</td>
#       <td>0</td>
#       <td>917</td>
#       <td>AL</td>
#     </tr>
#     <tr>
#       <td>BWMD-MID</td>
#       <td>1546</td>
#       <td>399</td>
#       <td>336</td>
#       <td>27</td>
#       <td>12</td>
#       <td>771</td>
#       <td>ALCHI(D)</td>
#     </tr>
#     <tr>
#       <td>CDCO</td>
#       <td>60</td>
#       <td>0</td>
#       <td>3</td>
#       <td>0</td>
#       <td>0</td>
#       <td>34</td>
#       <td>AL</td>
#     </tr>
#     <tr>
#       <td>CIF-core</td>
#       <td>321</td>
#       <td>87</td>
#       <td>31</td>
#       <td>1</td>
#       <td>1</td>
#       <td>176</td>
#       <td>AL(D)</td>
#     </tr>
#     <tr>
#       <td>CMSO</td>
#       <td>508</td>
#       <td>116</td>
#       <td>40</td>
#       <td>19</td>
#       <td>28</td>
#       <td>270</td>
#       <td>ALUHI(D)</td>
#     </tr>
#     <tr>
#       <td>CSO</td>
#       <td>374</td>
#       <td>136</td>
#       <td>30</td>
#       <td>25</td>
#       <td>19</td>
#       <td>154</td>
#       <td>ALCIQ(D)</td>
#     </tr>
#     <tr>
#       <td>DEB</td>
#       <td>2135</td>
#       <td>1110</td>
#       <td>601</td>
#       <td>12</td>
#       <td>109</td>
#       <td>296</td>
#       <td>ALH(D)</td>
#     </tr>
#     <tr>
#       <td>DISO</td>
#       <td>373</td>
#       <td>135</td>
#       <td>38</td>
#       <td>33</td>
#       <td>12</td>
#       <td>147</td>
#       <td>ALCHIQ(D)</td>
#     </tr>
#     <tr>
#       <td>DSIM</td>
#       <td>492</td>
#       <td>179</td>
#       <td>41</td>
#       <td>45</td>
#       <td>33</td>
#       <td>185</td>
#       <td>SHIQ(D)</td>
#     </tr>
#     <tr>
#       <td>EMMO\_Datamodel</td>
#       <td>89</td>
#       <td>28</td>
#       <td>11</td>
#       <td>5</td>
#       <td>5</td>
#       <td>34</td>
#       <td>ALCHQ(D)</td>
#     </tr>
#     <tr>
#       <td>EMMO\_atomistic</td>
#       <td>64</td>
#       <td>19</td>
#       <td>18</td>
#       <td>3</td>
#       <td>1</td>
#       <td>34</td>
#       <td>ALEH(D)</td>
#     </tr>
#     <tr>
#       <td>EMMO\_crystallography</td>
#       <td>357</td>
#       <td>106</td>
#       <td>61</td>
#       <td>5</td>
#       <td>1</td>
#       <td>175</td>
#       <td>ALCIQ(D)</td>
#     </tr>
#     <tr>
#       <td>EMMO\_mappings</td>
#       <td>73</td>
#       <td>27</td>
#       <td>9</td>
#       <td>5</td>
#       <td>3</td>
#       <td>28</td>
#       <td>ALEHQ(D)</td>
#     </tr>
#     <tr>
#       <td>EMMO\_mechanical\_testing</td>
#       <td>1740</td>
#       <td>725</td>
#       <td>393</td>
#       <td>13</td>
#       <td>6</td>
#       <td>657</td>
#       <td>ALCHIQ(D)</td>
#     </tr>
#     <tr>
#       <td>EMMO\_microstructure</td>
#       <td>183</td>
#       <td>80</td>
#       <td>61</td>
#       <td>2</td>
#       <td>0</td>
#       <td>60</td>
#       <td>ALE</td>
#     </tr>
#     <tr>
#       <td>EXPO</td>
#       <td>2067</td>
#       <td>1019</td>
#       <td>325</td>
#       <td>78</td>
#       <td>0</td>
#       <td>646</td>
#       <td>ALCHN</td>
#     </tr>
#     <tr>
#       <td>FOAF</td>
#       <td>393</td>
#       <td>73</td>
#       <td>1</td>
#       <td>42</td>
#       <td>27</td>
#       <td>245</td>
#       <td>ALHIF(D)</td>
#     </tr>
#     <tr>
#       <td>GPO</td>
#       <td>673</td>
#       <td>268</td>
#       <td>200</td>
#       <td>24</td>
#       <td>0</td>
#       <td>216</td>
#       <td>ALCHI</td>
#     </tr>
#     <tr>
#       <td>IAO</td>
#       <td>3718</td>
#       <td>523</td>
#       <td>264</td>
#       <td>53</td>
#       <td>4</td>
#       <td>2777</td>
#       <td>SROIN(D)</td>
#     </tr>
#     <tr>
#       <td>LDO</td>
#       <td>69</td>
#       <td>3</td>
#       <td>6</td>
#       <td>0</td>
#       <td>0</td>
#       <td>37</td>
#       <td>AL</td>
#     </tr>
#     <tr>
#       <td>LPBFO</td>
#       <td>663</td>
#       <td>151</td>
#       <td>179</td>
#       <td>2</td>
#       <td>0</td>
#       <td>346</td>
#       <td>ALCH</td>
#     </tr>
#     <tr>
#       <td>MAMBO</td>
#       <td>632</td>
#       <td>400</td>
#       <td>57</td>
#       <td>35</td>
#       <td>63</td>
#       <td>57</td>
#       <td>SHIQ(D)</td>
#     </tr>
#     <tr>
#       <td>MDO</td>
#       <td>574</td>
#       <td>192</td>
#       <td>38</td>
#       <td>32</td>
#       <td>32</td>
#       <td>268</td>
#       <td>ALCQ(D)</td>
#     </tr>
#     <tr>
#       <td>MDS</td>
#       <td>1698</td>
#       <td>540</td>
#       <td>256</td>
#       <td>11</td>
#       <td>1</td>
#       <td>890</td>
#       <td>AL(D)</td>
#     </tr>
#     <tr>
#       <td>MOL\_BRINELL</td>
#       <td>16349</td>
#       <td>12818</td>
#       <td>37</td>
#       <td>17</td>
#       <td>4</td>
#       <td>191</td>
#       <td>AL(D)</td>
#     </tr>
#     <tr>
#       <td>MOL\_TENSILE</td>
#       <td>354</td>
#       <td>127</td>
#       <td>35</td>
#       <td>61</td>
#       <td>7</td>
#       <td>120</td>
#       <td>ALCHF(D)</td>
#     </tr>
#     <tr>
#       <td>MSEO</td>
#       <td>890</td>
#       <td>126</td>
#       <td>150</td>
#       <td>2</td>
#       <td>0</td>
#       <td>618</td>
#       <td>ALH</td>
#     </tr>
#     <tr>
#       <td>MSLE</td>
#       <td>181</td>
#       <td>97</td>
#       <td>82</td>
#       <td>0</td>
#       <td>2</td>
#       <td>0</td>
#       <td>ALC</td>
#     </tr>
#     <tr>
#       <td>MaterialsMine</td>
#       <td>427</td>
#       <td>178</td>
#       <td>26</td>
#       <td>27</td>
#       <td>39</td>
#       <td>159</td>
#       <td>ALUHI(D)</td>
#     </tr>
#     <tr>
#       <td>NanoMine</td>
#       <td>815</td>
#       <td>229</td>
#       <td>172</td>
#       <td>1</td>
#       <td>0</td>
#       <td>429</td>
#       <td>ALEO</td>
#     </tr>
#     <tr>
#       <td>OA</td>
#       <td>295</td>
#       <td>64</td>
#       <td>25</td>
#       <td>8</td>
#       <td>11</td>
#       <td>204</td>
#       <td>AL(D)</td>
#     </tr>
#     <tr>
#       <td>OBO</td>
#       <td>602</td>
#       <td>192</td>
#       <td>36</td>
#       <td>40</td>
#       <td>0</td>
#       <td>323</td>
#       <td>SHIF</td>
#     </tr>
#     <tr>
#       <td>OEO</td>
#       <td>5</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>AL</td>
#     </tr>
#     <tr>
#       <td>OIEcharacterisation-methods</td>
#       <td>129</td>
#       <td>43</td>
#       <td>44</td>
#       <td>0</td>
#       <td>0</td>
#       <td>44</td>
#       <td>AL</td>
#     </tr>
#     <tr>
#       <td>OIEmanufacturing</td>
#       <td>763</td>
#       <td>236</td>
#       <td>228</td>
#       <td>5</td>
#       <td>0</td>
#       <td>304</td>
#       <td>ALEHI</td>
#     </tr>
#     <tr>
#       <td>OIEmaterials</td>
#       <td>460</td>
#       <td>138</td>
#       <td>119</td>
#       <td>1</td>
#       <td>0</td>
#       <td>204</td>
#       <td>ALC</td>
#     </tr>
#     <tr>
#       <td>OIEmodels</td>
#       <td>353</td>
#       <td>115</td>
#       <td>114</td>
#       <td>5</td>
#       <td>0</td>
#       <td>130</td>
#       <td>ALEHI</td>
#     </tr>
#     <tr>
#       <td>OIEsoftware</td>
#       <td>479</td>
#       <td>168</td>
#       <td>159</td>
#       <td>0</td>
#       <td>0</td>
#       <td>156</td>
#       <td>AL</td>
#     </tr>
#     <tr>
#       <td>OSMO</td>
#       <td>1786</td>
#       <td>1110</td>
#       <td>173</td>
#       <td>152</td>
#       <td>46</td>
#       <td>360</td>
#       <td>SROIN(D)</td>
#     </tr>
#     <tr>
#       <td>P-Plan</td>
#       <td>101</td>
#       <td>29</td>
#       <td>11</td>
#       <td>9</td>
#       <td>0</td>
#       <td>45</td>
#       <td>ALIF+</td>
#     </tr>
#     <tr>
#       <td>PLDO</td>
#       <td>212</td>
#       <td>30</td>
#       <td>11</td>
#       <td>2</td>
#       <td>7</td>
#       <td>126</td>
#       <td>ALH(D)</td>
#     </tr>
#     <tr>
#       <td>PMDCO</td>
#       <td>2240</td>
#       <td>390</td>
#       <td>265</td>
#       <td>36</td>
#       <td>8</td>
#       <td>15
