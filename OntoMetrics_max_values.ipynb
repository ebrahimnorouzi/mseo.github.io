# %%
import xml.etree.ElementTree as ET
import pandas as pd
import pickle



def extract_metric(tree_element):
    metric_family = tree_element.tag
    #print(metric_family)
    for child in tree_element:
        #print("---- ", child)
        metric_document = {}
        # if metric_document["metric_family"] == "ClassMetrics":
        #     metric_document["metric_family"] =  metric_family
        #     print(child)
        #     exit()
        #     metric_document["metric_name"] = child.tag
        #     metric_document["value"] = child.text 
        #     print(metric_document)
        # else:
        metric_document["metric_family"] =  metric_family
        metric_document["metric_name"] = child.tag
        metric_document["value"] = child.text 
        #print(metric_document)
        yield metric_document

def load_metrics(filename: str, ontology_name: str) -> pd.DataFrame:
    tree = ET.parse(filename)
    root = tree.getroot()
    metrics = []
    for child in root[0]:
        if child.tag == "Classmetrics": ## we don't handle class metrics
            #print(child)
            continue
            #exit()
            #for metric_document in extract_metric(child):
                #print(metric_document)
                #metrics.append(metric_document)
                #exit()
        for metric_document in extract_metric(child):
            metrics.append(metric_document)
    df = pd.DataFrame(metrics).rename(columns={"metric_name": "metric_code", "value": ontology_name})
    return df

def add_metrics(df_metrics: pd.DataFrame, df_new_metrics: pd.DataFrame) -> pd.DataFrame:
    selected_columns = list(set(df_new_metrics.columns) -  set(['metric_family']))
    df_new_table = df_metrics.merge(df_new_metrics[selected_columns],how='left', on= "metric_code")
    return df_new_table

df_all = pd.read_csv("output2_mse.csv")
df_metrics_table = pd.read_excel("metrics_labels2.xlsx")

# %%
df_metrics_table = df_metrics_table[["metric_name","metric_code","ontometrics_name","evaluation_criteria"]]
evaluated_ontologies = []

filename = 'all_files/SAREF.xml'

df_ = load_metrics(filename, df_all['namespace'][23])

df_metrics_table = add_metrics(df_metrics_table, df_)


df_
# Out:
#     metric_family          metric_code MatOnto
# 0     Basemetrics               Axioms     631
# 1     Basemetrics   Logicalaxiomscount     226
# 2     Basemetrics           Classcount      81
# 3     Basemetrics    Totalclassescount      81
# 4     Basemetrics  Objectpropertycount      35
# ..            ...                  ...     ...
# 148  ClassMetrics                Class      \n
# 149  ClassMetrics                Class      \n
# 150  ClassMetrics                Class      \n
# 151  ClassMetrics                Class      \n
# 152  ClassMetrics                Class      \n
#
# [153 rows x 3 columns]

# %%
tree = ET.parse(filename)
root = tree.getroot()
metrics = []
metric_document = {}
ClassMetrics = ['Classconnectivity',
'Classfulness',
'Classimportance',
'Classinheritancerichness',
'Classreadability',
'Classrelationshiprichness',
'Classchildrencount',
'Classinstancescount',
'Classpropertiescount']

for child in root[0]:
    if child.tag == "ClassMetrics":
        child_l_ = []
        child_l_names = []
        for child_ in child:
            child_l = []
            child_l_names.append(child_.attrib.get('iri'))
            for child_2 in child_:
                print(child_2)
                child_l.append(int(float(child_2.text)))
            child_l_.append(child_l)
        transposed_data = zip(*child_l_)

        # Calculate max, min, and average for each column
        max_values = [max(column) for column in transposed_data]
        min_values = [min(column) for column in transposed_data]
        avg_values = [sum(column) / len(column) for column in transposed_data]
        for j in range(9):
            for ii in [i for i, sublist in enumerate(child_l_) if sublist[j] == max_values[j] and max_values[j] != 0]:
                continue
        print(max_values[j], child_l_names[0])
        metric_document["metric_family"] =  "ClassMetrics"
        metric_document["metric_name"] = ClassMetrics[j]
        metric_document["value"] = child_l_names[0]
        #child_l_names[child_l_.index(max_values)]
        
        #max_indices = [i for i, column in enumerate(transposed_data) if max(column) == max_values[i]]

        # Map the indices to the corresponding data names
        #max_names = [child_l_names[index] for index in max_indices]

        # Map the indices to the corresponding data names

        #print(max_names)
        #print("Max values:", max_values)
        #print("Min values:", min_values)
        #print("Avg values:", avg_values)
        
            #max(child_max)
            #metric_document = {}
            # if metric_document["metric_family"] == "ClassMetrics":
            #     metric_document["metric_family"] =  metric_family
            #     print(child)
            #     exit()
            #     metric_document["metric_name"] = child.tag
            #     metric_document["value"] = child.text 
            #     print(metric_document)
            # else:
            #metric_document["metric_family"] =  metric_family
            #metric_document["metric_name"] = child.tag
            #metric_document["value"] = child.text 
        #print(metric_document)
        #continue
        #exit()
        #for metric_document in extract_metric(child):
            #print(metric_document)
            #metrics.append(metric_document)
            #exit()
    #for metric_document in extract_metric(child):
        #print(metric_document)
        #metrics.append(metric_document)
    #print(child.tag)
#metrics
#df_ = pd.DataFrame(metrics).rename(columns={"metric_name": "metric_code", "value": df_all['namespace'][28]})
# Out:
# <Element 'Classconnectivity' at 0x0000022947EC6A20>
# <Element 'Classfulness' at 0x0000022947EC4F90>
# <Element 'Classimportance' at 0x0000022947EC7B50>
# <Element 'Classinheritancerichness' at 0x0000022947EC6BB0>
# <Element 'Classreadability' at 0x0000022947EC5620>
# <Element 'Classrelationshiprichness' at 0x0000022947EC5AD0>
# <Element 'Classchildrencount' at 0x0000022947EC56C0>
# <Element 'Classinstancescount' at 0x0000022947EC4CC0>
# <Element 'Classpropertiescount' at 0x0000022947EC7420>
# <Element 'Classconnectivity' at 0x0000022947EC5580>
# <Element 'Classfulness' at 0x0000022947EC5CB0>
# <Element 'Classimportance' at 0x0000022947EC47C0>
# <Element 'Classinheritancerichness' at 0x0000022947EC7DD0>
# <Element 'Classreadability' at 0x0000022947EC5170>
# <Element 'Classrelationshiprichness' at 0x0000022947EC75B0>
# <Element 'Classchildrencount' at 0x0000022947EC66B0>
# <Element 'Classinstancescount' at 0x0000022947EC40E0>
# <Element 'Classpropertiescount' at 0x0000022947EC5E40>
# <Element 'Classconnectivity' at 0x0000022947EC6480>
# <Element 'Classfulness' at 0x0000022947EC4B80>
# <Element 'Classimportance' at 0x0000022947EC54E0>
# <Element 'Classinheritancerichness' at 0x0000022947EC44A0>
# <Element 'Classreadability' at 0x0000022947EC41D0>
# <Element 'Classrelationshiprichness' at 0x0000022947EC7970>
# <Element 'Classchildrencount' at 0x0000022947EC79C0>
# <Element 'Classinstancescount' at 0x0000022947EC7740>
# <Element 'Classpropertiescount' at 0x0000022947EC7E70>
# <Element 'Classconnectivity' at 0x0000022947EC68E0>
# <Element 'Classfulness' at 0x0000022947EC4F40>
# <Element 'Classimportance' at 0x0000022947EC5DF0>
# <Element 'Classinheritancerichness' at 0x0000022947EC6110>
# <Element 'Classreadability' at 0x0000022947EC4C70>
# <Element 'Classrelationshiprichness' at 0x0000022947EC6070>
# <Element 'Classchildrencount' at 0x0000022947EC43B0>
# <Element 'Classinstancescount' at 0x0000022947EC7C40>
# <Element 'Classpropertiescount' at 0x0000022947EC6250>
# <Element 'Classconnectivity' at 0x0000022947EC6A70>
# <Element 'Classfulness' at 0x0000022947EC7240>
# <Element 'Classimportance' at 0x0000022947EC76A0>
# <Element 'Classinheritancerichness' at 0x0000022947EC5490>
# <Element 'Classreadability' at 0x0000022947EC6430>
# <Element 'Classrelationshiprichness' at 0x0000022947EC6CA0>
# <Element 'Classchildrencount' at 0x0000022947EC4630>
# <Element 'Classinstancescount' at 0x0000022947EC7650>
# <Element 'Classpropertiescount' at 0x0000022947EC62F0>
# <Element 'Classconnectivity' at 0x0000022947EC52B0>
# <Element 'Classfulness' at 0x0000022947EC5080>
# <Element 'Classimportance' at 0x0000022947EC6ED0>
# <Element 'Classinheritancerichness' at 0x0000022947EC61B0>
# <Element 'Classreadability' at 0x0000022947EC60C0>
# <Element 'Classrelationshiprichness' at 0x0000022947EC5850>
# <Element 'Classchildrencount' at 0x0000022947EC7D80>
# <Element 'Classinstancescount' at 0x0000022947EC5710>
# <Element 'Classpropertiescount' at 0x0000022947EC69D0>
# <Element 'Classconnectivity' at 0x0000022947EC5A30>
# <Element 'Classfulness' at 0x0000022947EC4180>
# <Element 'Classimportance' at 0x0000022947EC4DB0>
# <Element 'Classinheritancerichness' at 0x0000022947EC6200>
# <Element 'Classreadability' at 0x0000022947EC6E80>
# <Element 'Classrelationshiprichness' at 0x0000022947EC44F0>
# <Element 'Classchildrencount' at 0x0000022947EC7150>
# <Element 'Classinstancescount' at 0x0000022947EC7BA0>
# <Element 'Classpropertiescount' at 0x0000022947EC5DA0>
# <Element 'Classconnectivity' at 0x0000022947EC7C90>
# <Element 'Classfulness' at 0x0000022947EC6020>
# <Element 'Classimportance' at 0x0000022947EC4450>
# <Element 'Classinheritancerichness' at 0x0000022947EC6340>
# <Element 'Classreadability' at 0x0000022947EC7AB0>
# <Element 'Classrelationshiprichness' at 0x0000022947EC4720>
# <Element 'Classchildrencount' at 0x0000022947EC5B70>
# <Element 'Classinstancescount' at 0x0000022947EC5940>
# <Element 'Classpropertiescount' at 0x0000022947EC59E0>
# <Element 'Classconnectivity' at 0x0000022947EC4770>
# <Element 'Classfulness' at 0x0000022947EC67F0>
# <Element 'Classimportance' at 0x0000022947EC6AC0>
# <Element 'Classinheritancerichness' at 0x0000022947EC4E50>
# <Element 'Classreadability' at 0x0000022947EC62A0>
# <Element 'Classrelationshiprichness' at 0x0000022947EC5A80>
# <Element 'Classchildrencount' at 0x0000022947EC7F10>
# <Element 'Classinstancescount' at 0x0000022947EC63E0>
# <Element 'Classpropertiescount' at 0x0000022947EC7D30>
# <Element 'Classconnectivity' at 0x0000022947EC45E0>
# <Element 'Classfulness' at 0x0000022947EC7560>
# <Element 'Classimportance' at 0x0000022947EC6D90>
# <Element 'Classinheritancerichness' at 0x0000022947EC73D0>
# <Element 'Classreadability' at 0x0000022947EC65C0>
# <Element 'Classrelationshiprichness' at 0x0000022947EC5D00>
# <Element 'Classchildrencount' at 0x0000022947EC5530>
# <Element 'Classinstancescount' at 0x0000022947EC4E00>
# <Element 'Classpropertiescount' at 0x0000022947EC6610>
# <Element 'Classconnectivity' at 0x0000022947EC7470>
# <Element 'Classfulness' at 0x0000022947EC49F0>
# <Element 'Classimportance' at 0x0000022947EC78D0>
# <Element 'Classinheritancerichness' at 0x0000022947EC6660>
# <Element 'Classreadability' at 0x0000022947EC74C0>
# <Element 'Classrelationshiprichness' at 0x0000022947EC5440>
# <Element 'Classchildrencount' at 0x0000022947EC6930>
# <Element 'Classinstancescount' at 0x0000022947EC6750>
# <Element 'Classpropertiescount' at 0x0000022947EC4310>
# <Element 'Classconnectivity' at 0x0000022947EC49A0>
# <Element 'Classfulness' at 0x0000022947EC4130>
# <Element 'Classimportance' at 0x0000022947EC5030>
# <Element 'Classinheritancerichness' at 0x0000022947EC6520>
# <Element 'Classreadability' at 0x0000022947EC4A40>
# <Element 'Classrelationshiprichness' at 0x0000022947EC71A0>
# <Element 'Classchildrencount' at 0x0000022947EC77E0>
# <Element 'Classinstancescount' at 0x0000022947EC4D60>
# <Element 'Classpropertiescount' at 0x0000022947EC5300>
# <Element 'Classconnectivity' at 0x0000022947EC5210>
# <Element 'Classfulness' at 0x0000022947EC5670>
# <Element 'Classimportance' at 0x0000022947EC53F0>
# <Element 'Classinheritancerichness' at 0x0000022947EC4040>
# <Element 'Classreadability' at 0x0000022947EC6390>
# <Element 'Classrelationshiprichness' at 0x0000022947EC7F60>
# <Element 'Classchildrencount' at 0x0000022947EC7290>
# <Element 'Classinstancescount' at 0x0000022947EC7E20>
# <Element 'Classpropertiescount' at 0x0000022947EC5990>
# <Element 'Classconnectivity' at 0x0000022947EC7A60>
# <Element 'Classfulness' at 0x0000022947EC4270>
# <Element 'Classimportance' at 0x0000022947DDE7A0>
# <Element 'Classinheritancerichness' at 0x0000022947DDF380>
# <Element 'Classreadability' at 0x0000022947DDEFC0>
# <Element 'Classrelationshiprichness' at 0x0000022947DDFC40>
# <Element 'Classchildrencount' at 0x0000022947DDD990>
# <Element 'Classinstancescount' at 0x0000022947DDF740>
# <Element 'Classpropertiescount' at 0x0000022947DDE390>
# <Element 'Classconnectivity' at 0x0000022947DDE250>
# <Element 'Classfulness' at 0x0000022947DDE4D0>
# <Element 'Classimportance' at 0x0000022947DDF510>
# <Element 'Classinheritancerichness' at 0x0000022947DDEED0>
# <Element 'Classreadability' at 0x0000022947DDEA70>
# <Element 'Classrelationshiprichness' at 0x0000022947DDE2A0>
# <Element 'Classchildrencount' at 0x0000022947DDE3E0>
# <Element 'Classinstancescount' at 0x0000022947DDDBC0>
# <Element 'Classpropertiescount' at 0x0000022947DDD5D0>
# <Element 'Classconnectivity' at 0x0000022947DDDC60>
# <Element 'Classfulness' at 0x0000022947DDDCB0>
# <Element 'Classimportance' at 0x0000022947DDDD00>
# <Element 'Classinheritancerichness' at 0x0000022947DDE570>
# <Element 'Classreadability' at 0x0000022947DDE430>
# <Element 'Classrelationshiprichness' at 0x0000022947DDF0B0>
# <Element 'Classchildrencount' at 0x0000022947DDDEE0>
# <Element 'Classinstancescount' at 0x0000022947DDEE30>
# <Element 'Classpropertiescount' at 0x0000022947DDDF30>
# <Element 'Classconnectivity' at 0x0000022947D0A570>
# <Element 'Classfulness' at 0x0000022947D08630>
# <Element 'Classimportance' at 0x0000022947D0A7F0>
# <Element 'Classinheritancerichness' at 0x0000022947D09120>
# <Element 'Classreadability' at 0x0000022947D0B600>
# <Element 'Classrelationshiprichness' at 0x0000022947D0BAB0>
# <Element 'Classchildrencount' at 0x0000022947D08C20>
# <Element 'Classinstancescount' at 0x0000022947D08770>
# <Element 'Classpropertiescount' at 0x0000022947D08BD0>
# <Element 'Classconnectivity' at 0x0000022947D0B880>
# <Element 'Classfulness' at 0x0000022947D09DF0>
# <Element 'Classimportance' at 0x0000022947D08180>
# <Element 'Classinheritancerichness' at 0x0000022947D08F40>
# <Element 'Classreadability' at 0x0000022947D0AED0>
# <Element 'Classrelationshiprichness' at 0x0000022947D0BBF0>
# <Element 'Classchildrencount' at 0x0000022947D0AA70>
# <Element 'Classinstancescount' at 0x0000022947D0BD30>
# <Element 'Classpropertiescount' at 0x0000022947D0A070>
# <Element 'Classconnectivity' at 0x0000022947D0A7A0>
# <Element 'Classfulness' at 0x0000022947D09C60>
# <Element 'Classimportance' at 0x0000022947D0B7E0>
# <Element 'Classinheritancerichness' at 0x0000022947D0B0B0>
# <Element 'Classreadability' at 0x0000022947D0AD90>
# <Element 'Classrelationshiprichness' at 0x0000022947D0B970>
# <Element 'Classchildrencount' at 0x0000022947D0A5C0>
# <Element 'Classinstancescount' at 0x0000022947D0AF20>
# <Element 'Classpropertiescount' at 0x0000022947D0B9C0>
# <Element 'Classconnectivity' at 0x0000022947D0B010>
# <Element 'Classfulness' at 0x0000022947D0B100>
# <Element 'Classimportance' at 0x0000022947D0A160>
# <Element 'Classinheritancerichness' at 0x0000022947D09850>
# <Element 'Classreadability' at 0x0000022947D0BF10>
# <Element 'Classrelationshiprichness' at 0x0000022947D09030>
# <Element 'Classchildrencount' at 0x0000022947D0BA10>
# <Element 'Classinstancescount' at 0x0000022947D09AD0>
# <Element 'Classpropertiescount' at 0x0000022947D0AB60>
# <Element 'Classconnectivity' at 0x0000022947D0B420>
# <Element 'Classfulness' at 0x0000022947D08D60>
# <Element 'Classimportance' at 0x0000022947D089F0>
# <Element 'Classinheritancerichness' at 0x0000022947D0BC40>
# <Element 'Classreadability' at 0x0000022947D0A6B0>
# <Element 'Classrelationshiprichness' at 0x0000022947D082C0>
# <Element 'Classchildrencount' at 0x0000022947D0A390>
# <Element 'Classinstancescount' at 0x0000022947E7DEE0>
# <Element 'Classpropertiescount' at 0x0000022947E7ED40>
# <Element 'Classconnectivity' at 0x0000022947E7EF20>
# <Element 'Classfulness' at 0x0000022947E7E520>
# <Element 'Classimportance' at 0x0000022947E7C4F0>
# <Element 'Classinheritancerichness' at 0x0000022947E7DB20>
# <Element 'Classreadability' at 0x0000022947E7FBF0>
# <Element 'Classrelationshiprichness' at 0x0000022947E7F100>
# <Element 'Classchildrencount' at 0x0000022947E7E8E0>
# <Element 'Classinstancescount' at 0x0000022947E7E3E0>
# <Element 'Classpropertiescount' at 0x0000022947E7F150>
# <Element 'Classconnectivity' at 0x0000022947E7C180>
# <Element 'Classfulness' at 0x0000022947E7FC90>
# <Element 'Classimportance' at 0x0000022947E7F7E0>
# <Element 'Classinheritancerichness' at 0x0000022947E7D6C0>
# <Element 'Classreadability' at 0x0000022947E7D7B0>
# <Element 'Classrelationshiprichness' at 0x0000022947E7D4E0>
# <Element 'Classchildrencount' at 0x0000022947E7FD30>
# <Element 'Classinstancescount' at 0x0000022947E7D0D0>
# <Element 'Classpropertiescount' at 0x0000022947E7C7C0>
# <Element 'Classconnectivity' at 0x0000022947E7E890>
# <Element 'Classfulness' at 0x0000022947E7ECA0>
# <Element 'Classimportance' at 0x0000022947E7DCB0>
# <Element 'Classinheritancerichness' at 0x0000022947E7C630>
# <Element 'Classreadability' at 0x0000022947E7CA40>
# <Element 'Classrelationshiprichness' at 0x0000022947E7E570>
# <Element 'Classchildrencount' at 0x0000022947E7E750>
# <Element 'Classinstancescount' at 0x0000022947E7FBA0>
# <Element 'Classpropertiescount' at 0x0000022947E7FE70>
# <Element 'Classconnectivity' at 0x0000022947E7DA30>
# <Element 'Classfulness' at 0x0000022947E7FE20>
# <Element 'Classimportance' at 0x0000022947E7F060>
# <Element 'Classinheritancerichness' at 0x0000022947E7EB10>
# <Element 'Classreadability' at 0x0000022947E7CFE0>
# <Element 'Classrelationshiprichness' at 0x0000022947E7F470>
# <Element 'Classchildrencount' at 0x0000022947E7F8D0>
# <Element 'Classinstancescount' at 0x0000022947E7E9D0>
# <Element 'Classpropertiescount' at 0x0000022947E7DC60>
# <Element 'Classconnectivity' at 0x0000022947E7FB50>
# <Element 'Classfulness' at 0x0000022947E7EA70>
# <Element 'Classimportance' at 0x0000022947E7FDD0>
# <Element 'Classinheritancerichness' at 0x0000022947E7DBC0>
# <Element 'Classreadability' at 0x0000022947E7DC10>
# <Element 'Classrelationshiprichness' at 0x0000022947E7C270>
# <Element 'Classchildrencount' at 0x0000022947E7E250>
# <Element 'Classinstancescount' at 0x0000022947E7EA20>
# <Element 'Classpropertiescount' at 0x0000022947E7D9E0>
# <Element 'Classconnectivity' at 0x0000022947E7EB60>
# <Element 'Classfulness' at 0x0000022947E7DA80>
# <Element 'Classimportance' at 0x0000022947E7D8F0>
# <Element 'Classinheritancerichness' at 0x0000022947E7D3F0>
# <Element 'Classreadability' at 0x0000022947E7D710>
# <Element 'Classrelationshiprichness' at 0x0000022947E7DD00>
# <Element 'Classchildrencount' at 0x0000022947E7F740>
# <Element 'Classinstancescount' at 0x0000022947E7E840>
# <Element 'Classpropertiescount' at 0x0000022947E7FF60>
# <Element 'Classconnectivity' at 0x0000022947E7E2A0>
# <Element 'Classfulness' at 0x0000022947E7C680>
# <Element 'Classimportance' at 0x0000022947E7D940>
# <Element 'Classinheritancerichness' at 0x0000022947E7E390>
# <Element 'Classreadability' at 0x0000022947E7FF10>
# <Element 'Classrelationshiprichness' at 0x0000022947E7F790>
# <Element 'Classchildrencount' at 0x0000022947E7F290>
# <Element 'Classinstancescount' at 0x0000022947E7E5C0>
# <Element 'Classpropertiescount' at 0x0000022947E7CF90>
# <Element 'Classconnectivity' at 0x0000022947E7C220>
# <Element 'Classfulness' at 0x0000022947E7CC70>
# <Element 'Classimportance' at 0x0000022947E7F330>
# <Element 'Classinheritancerichness' at 0x0000022947E7C090>
# <Element 'Classreadability' at 0x0000022947E7E160>
# <Element 'Classrelationshiprichness' at 0x0000022947E7FA60>
# <Element 'Classchildrencount' at 0x0000022947E7CDB0>
# <Element 'Classinstancescount' at 0x0000022947E7E200>
# <Element 'Classpropertiescount' at 0x0000022947E7FB00>
# <Element 'Classconnectivity' at 0x0000022947E7E020>
# <Element 'Classfulness' at 0x0000022947E7CBD0>
# <Element 'Classimportance' at 0x0000022947E7DE40>
# <Element 'Classinheritancerichness' at 0x0000022947E7C950>
# <Element 'Classreadability' at 0x0000022947E7C040>
# <Element 'Classrelationshiprichness' at 0x0000022947E7FA10>
# <Element 'Classchildrencount' at 0x0000022947E7E070>
# <Element 'Classinstancescount' at 0x0000022947E7F920>
# <Element 'Classpropertiescount' at 0x0000022947E7F600>
# <Element 'Classconnectivity' at 0x0000022947E7D080>
# <Element 'Classfulness' at 0x0000022947E7F5B0>
# <Element 'Classimportance' at 0x0000022947E7E1B0>
# <Element 'Classinheritancerichness' at 0x0000022947E7F510>
# <Element 'Classreadability' at 0x0000022947E7D300>
# <Element 'Classrelationshiprichness' at 0x0000022947E7DFD0>
# <Element 'Classchildrencount' at 0x0000022947E7CF40>
# <Element 'Classinstancescount' at 0x0000022947E7DE90>
# <Element 'Classpropertiescount' at 0x0000022947E7CCC0>
# <Element 'Classconnectivity' at 0x0000022947E7C4A0>
# <Element 'Classfulness' at 0x0000022947E7D210>
# <Element 'Classimportance' at 0x0000022947E7D760>
# <Element 'Classinheritancerichness' at 0x0000022947E7CEA0>
# <Element 'Classreadability' at 0x0000022947E7CB80>
# <Element 'Classrelationshiprichness' at 0x0000022947E7D620>
# <Element 'Classchildrencount' at 0x0000022947E7D530>
# <Element 'Classinstancescount' at 0x0000022947E7DAD0>
# <Element 'Classpropertiescount' at 0x0000022947E7D8A0>
# <Element 'Classconnectivity' at 0x0000022945037DD0>
# <Element 'Classfulness' at 0x0000022947DD1490>
# <Element 'Classimportance' at 0x0000022947DD0900>
# <Element 'Classinheritancerichness' at 0x0000022947DD38D0>
# <Element 'Classreadability' at 0x0000022947DD1AD0>
# <Element 'Classrelationshiprichness' at 0x0000022947DD3EC0>
# <Element 'Classchildrencount' at 0x0000022947DD27F0>
# <Element 'Classinstancescount' at 0x0000022947DD0180>
# <Element 'Classpropertiescount' at 0x0000022947DD3FB0>
# <Element 'Classconnectivity' at 0x0000022947DD1300>
# <Element 'Classfulness' at 0x0000022947DD1080>
# <Element 'Classimportance' at 0x0000022947DD3650>
# <Element 'Classinheritancerichness' at 0x0000022947DD37E0>
# <Element 'Classreadability' at 0x0000022947DD0950>
# <Element 'Classrelationshiprichness' at 0x0000022947DD0310>
# <Element 'Classchildrencount' at 0x0000022947DD0C70>
# <Element 'Classinstancescount' at 0x0000022947DD2340>
# <Element 'Classpropertiescount' at 0x0000022947DD1440>
# <Element 'Classconnectivity' at 0x0000022947DD1FD0>
# <Element 'Classfulness' at 0x0000022947DD2A70>
# <Element 'Classimportance' at 0x0000022947DD32E0>
# <Element 'Classinheritancerichness' at 0x0000022947DD2FC0>
# <Element 'Classreadability' at 0x0000022947DD2930>
# <Element 'Classrelationshiprichness' at 0x0000022947DD2C00>
# <Element 'Classchildrencount' at 0x0000022947DD3740>
# <Element 'Classinstancescount' at 0x0000022947DD3330>
# <Element 'Classpropertiescount' at 0x0000022947DD1E90>
# <Element 'Classconnectivity' at 0x0000022947DD05E0>
# <Element 'Classfulness' at 0x0000022947DD26B0>
# <Element 'Classimportance' at 0x0000022947DD0360>
# <Element 'Classinheritancerichness' at 0x0000022947DD1D00>
# <Element 'Classreadability' at 0x0000022947DD2840>
# <Element 'Classrelationshiprichness' at 0x0000022947DD3470>
# <Element 'Classchildrencount' at 0x0000022947DD3BF0>
# <Element 'Classinstancescount' at 0x0000022947DD3150>
# <Element 'Classpropertiescount' at 0x0000022947DD17B0>
# <Element 'Classconnectivity' at 0x0000022947DD0EA0>
# <Element 'Classfulness' at 0x0000022947DD3240>
# <Element 'Classimportance' at 0x0000022947DD11C0>
# <Element 'Classinheritancerichness' at 0x0000022947DD0D10>
# <Element 'Classreadability' at 0x0000022947DD3970>
# <Element 'Classrelationshiprichness' at 0x0000022947DD1F30>
# <Element 'Classchildrencount' at 0x0000022947DD3060>
# <Element 'Classinstancescount' at 0x0000022947DD3A10>
# <Element 'Classpropertiescount' at 0x0000022947DD1800>
# <Element 'Classconnectivity' at 0x0000022947DD1620>
# <Element 'Classfulness' at 0x0000022947DD3560>
# <Element 'Classimportance' at 0x0000022947DD0810>
# <Element 'Classinheritancerichness' at 0x0000022947DD1B20>
# <Element 'Classreadability' at 0x0000022947DD2200>
# <Element 'Classrelationshiprichness' at 0x0000022947DD2430>
# <Element 'Classchildrencount' at 0x0000022947DD3C40>
# <Element 'Classinstancescount' at 0x0000022947DD20C0>
# <Element 'Classpropertiescount' at 0x0000022947DD19E0>
# <Element 'Classconnectivity' at 0x0000022947DD3F60>
# <Element 'Classfulness' at 0x0000022947DD2C50>
# <Element 'Classimportance' at 0x0000022947DD1A80>
# <Element 'Classinheritancerichness' at 0x0000022947DD16C0>
# <Element 'Classreadability' at 0x0000022947DD2480>
# <Element 'Classrelationshiprichness' at 0x0000022947DD1DA0>
# <Element 'Classchildrencount' at 0x0000022947DD1350>
# <Element 'Classinstancescount' at 0x0000022947DD36F0>
# <Element 'Classpropertiescount' at 0x0000022947DD0090>
# <Element 'Classconnectivity' at 0x0000022947DD06D0>
# <Element 'Classfulness' at 0x0000022947DD04A0>
# <Element 'Classimportance' at 0x0000022947DD2020>
# <Element 'Classinheritancerichness' at 0x0000022947DD35B0>
# <Element 'Classreadability' at 0x0000022947DD1850>
# <Element 'Classrelationshiprichness' at 0x0000022947DD3920>
# <Element 'Classchildrencount' at 0x0000022947DD0400>
# <Element 'Classinstancescount' at 0x0000022947DD1F80>
# <Element 'Classpropertiescount' at 0x0000022947DD2750>
# <Element 'Classconnectivity' at 0x0000022947DD2D40>
# <Element 'Classfulness' at 0x0000022947DD3420>
# <Element 'Classimportance' at 0x0000022947DD24D0>
# <Element 'Classinheritancerichness' at 0x0000022947DD1CB0>
# <Element 'Classreadability' at 0x0000022947DD3F10>
# <Element 'Classrelationshiprichness' at 0x0000022947DD3CE0>
# <Element 'Classchildrencount' at 0x0000022947DD27A0>
# <Element 'Classinstancescount' at 0x0000022947DD0770>
# <Element 'Classpropertiescount' at 0x0000022947DD18F0>
# <Element 'Classconnectivity' at 0x0000022947DD2A20>
# <Element 'Classfulness' at 0x0000022947DD30B0>
# <Element 'Classimportance' at 0x0000022947DD0BD0>
# <Element 'Classinheritancerichness' at 0x0000022947DD2890>
# <Element 'Classreadability' at 0x0000022947DD12B0>
# <Element 'Classrelationshiprichness' at 0x0000022947DD1C10>
# <Element 'Classchildrencount' at 0x0000022947DD0630>
# <Element 'Classinstancescount' at 0x0000022947DD31F0>
# <Element 'Classpropertiescount' at 0x0000022947DD3B50>
# <Element 'Classconnectivity' at 0x0000022947DD0A90>
# <Element 'Classfulness' at 0x0000022947DD2F70>
# <Element 'Classimportance' at 0x0000022947DD1580>
# <Element 'Classinheritancerichness' at 0x0000022947DD25C0>
# <Element 'Classreadability' at 0x0000022947DD2160>
# <Element 'Classrelationshiprichness' at 0x0000022947DD23E0>
# <Element 'Classchildrencount' at 0x0000022947DD1990>
# <Element 'Classinstancescount' at 0x0000022947DD2700>
# <Element 'Classpropertiescount' at 0x0000022947DD1170>
# <Element 'Classconnectivity' at 0x0000022947DD2DE0>
# <Element 'Classfulness' at 0x0000022947DD3290>
# <Element 'Classimportance' at 0x0000022947DD22F0>
# <Element 'Classinheritancerichness' at 0x0000022947DD2B60>
# <Element 'Classreadability' at 0x0000022947DD00E0>
# <Element 'Classrelationshiprichness' at 0x0000022947DD2B10>
# <Element 'Classchildrencount' at 0x0000022947DD15D0>
# <Element 'Classinstancescount' at 0x0000022947DD2CA0>
# <Element 'Classpropertiescount' at 0x0000022947DD2AC0>
# <Element 'Classconnectivity' at 0x0000022947DD1710>
# <Element 'Classfulness' at 0x0000022947DD09F0>
# <Element 'Classimportance' at 0x0000022947DD13A0>
# <Element 'Classinheritancerichness' at 0x0000022947DD29D0>
# <Element 'Classreadability' at 0x0000022947DD2ED0>
# <Element 'Classrelationshiprichness' at 0x0000022947DD0040>
# <Element 'Classchildrencount' at 0x0000022947DD3D30>
# <Element 'Classinstancescount' at 0x0000022947DD03B0>
# <Element 'Classpropertiescount' at 0x0000022947DD2980>
# <Element 'Classconnectivity' at 0x0000022947DD0680>
# <Element 'Classfulness' at 0x0000022947DD1260>
# <Element 'Classimportance' at 0x0000022947DD2110>
# <Element 'Classinheritancerichness' at 0x0000022947DD3510>
# <Element 'Classreadability' at 0x0000022947DD3880>
# <Element 'Classrelationshiprichness' at 0x0000022947DD2250>
# <Element 'Classchildrencount' at 0x0000022947DD2570>
# <Element 'Classinstancescount' at 0x0000022947DD2660>
# <Element 'Classpropertiescount' at 0x0000022947DD3DD0>
# <Element 'Classconnectivity' at 0x0000022947DD1530>
# <Element 'Classfulness' at 0x0000022947DD3380>
# <Element 'Classimportance' at 0x0000022947DD28E0>
# <Element 'Classinheritancerichness' at 0x0000022947DD2BB0>
# <Element 'Classreadability' at 0x0000022947DD1E40>
# <Element 'Classrelationshiprichness' at 0x0000022947DD2E30>
# <Element 'Classchildrencount' at 0x0000022947DD0B30>
# <Element 'Classinstancescount' at 0x0000022947DD0590>
# <Element 'Classpropertiescount' at 0x0000022947DD1DF0>
# <Element 'Classconnectivity' at 0x0000022947DD1BC0>
# <Element 'Classfulness' at 0x0000022947944C70>
# <Element 'Classimportance' at 0x0000022947946D40>
# <Element 'Classinheritancerichness' at 0x0000022947946ED0>
# <Element 'Classreadability' at 0x00000229479478D0>
# <Element 'Classrelationshiprichness' at 0x0000022947947010>
# <Element 'Classchildrencount' at 0x00000229479441D0>
# <Element 'Classinstancescount' at 0x00000229479463E0>
# <Element 'Classpropertiescount' at 0x0000022947946700>
# <Element 'Classconnectivity' at 0x0000022947946570>
# <Element 'Classfulness' at 0x0000022947947330>
# <Element 'Classimportance' at 0x00000229479466B0>
# <Element 'Classinheritancerichness' at 0x0000022947945440>
# <Element 'Classreadability' at 0x0000022947945210>
# <Element 'Classrelationshiprichness' at 0x0000022947945850>
# <Element 'Classchildrencount' at 0x0000022947944090>
# <Element 'Classinstancescount' at 0x0000022947945DA0>
# <Element 'Classpropertiescount' at 0x0000022947944EA0>
# <Element 'Classconnectivity' at 0x00000229479440E0>
# <Element 'Classfulness' at 0x0000022947944D60>
# <Element 'Classimportance' at 0x0000022947945120>
# <Element 'Classinheritancerichness' at 0x0000022947946390>
# <Element 'Classreadability' at 0x00000229479471A0>
# <Element 'Classrelationshiprichness' at 0x0000022947944360>
# <Element 'Classchildrencount' at 0x0000022947947510>
# <Element 'Classinstancescount' at 0x00000229479473D0>
# <Element 'Classpropertiescount' at 0x0000022947945080>
# <Element 'Classconnectivity' at 0x0000022947947EC0>
# <Element 'Classfulness' at 0x0000022947947380>
# <Element 'Classimportance' at 0x00000229479465C0>
# <Element 'Classinheritancerichness' at 0x0000022947945C10>
# <Element 'Classreadability' at 0x0000022947944C20>
# <Element 'Classrelationshiprichness' at 0x0000022947945FD0>
# <Element 'Classchildrencount' at 0x00000229479464D0>
# <Element 'Classinstancescount' at 0x0000022947945EE0>
# <Element 'Classpropertiescount' at 0x0000022947945F30>
# <Element 'Classconnectivity' at 0x00000229479454E0>
# <Element 'Classfulness' at 0x0000022947947470>
# <Element 'Classimportance' at 0x0000022947947790>
# <Element 'Classinheritancerichness' at 0x0000022947946B10>
# <Element 'Classreadability' at 0x0000022947944AE0>
# <Element 'Classrelationshiprichness' at 0x0000022947944450>
# <Element 'Classchildrencount' at 0x00000229479468E0>
# <Element 'Classinstancescount' at 0x0000022947946B60>
# <Element 'Classpropertiescount' at 0x0000022947945D00>
# <Element 'Classconnectivity' at 0x00000229479446D0>
# <Element 'Classfulness' at 0x0000022947944720>
# <Element 'Classimportance' at 0x0000022947944220>
# <Element 'Classinheritancerichness' at 0x0000022947947150>
# <Element 'Classreadability' at 0x00000229479452B0>
# <Element 'Classrelationshiprichness' at 0x0000022947945260>
# <Element 'Classchildrencount' at 0x0000022947947240>
# <Element 'Classinstancescount' at 0x00000229479470B0>
# <Element 'Classpropertiescount' at 0x00000229479453A0>
# <Element 'Classconnectivity' at 0x00000229479472E0>
# <Element 'Classfulness' at 0x0000022947946250>
# <Element 'Classimportance' at 0x0000022947945670>
# <Element 'Classinheritancerichness' at 0x00000229479449F0>
# <Element 'Classreadability' at 0x0000022947944130>
# <Element 'Classrelationshiprichness' at 0x0000022947944630>
# <Element 'Classchildrencount' at 0x00000229479461B0>
# <Element 'Classinstancescount' at 0x0000022947944D10>
# <Element 'Classpropertiescount' at 0x0000022947944590>
# <Element 'Classconnectivity' at 0x00000229479453F0>
# <Element 'Classfulness' at 0x00000229479447C0>
# <Element 'Classimportance' at 0x0000022947944A40>
# <Element 'Classinheritancerichness' at 0x00000229479476A0>
# <Element 'Classreadability' at 0x0000022947946AC0>
# <Element 'Classrelationshiprichness' at 0x0000022947946CA0>
# <Element 'Classchildrencount' at 0x0000022947945E40>
# <Element 'Classinstancescount' at 0x0000022947945530>
# <Element 'Classpropertiescount' at 0x00000229479458A0>
# <Element 'Classconnectivity' at 0x00000229479443B0>
# <Element 'Classfulness' at 0x00000229479451C0>
# <Element 'Classimportance' at 0x00000229479444F0>
# <Element 'Classinheritancerichness' at 0x0000022947946070>
# <Element 'Classreadability' at 0x0000022947947E20>
# <Element 'Classrelationshiprichness' at 0x0000022947947F10>
# <Element 'Classchildrencount' at 0x0000022947947100>
# <Element 'Classinstancescount' at 0x0000022947945350>
# <Element 'Classpropertiescount' at 0x0000022947947420>
# <Element 'Classconnectivity' at 0x0000022947947C90>
# <Element 'Classfulness' at 0x0000022947945170>
# <Element 'Classimportance' at 0x0000022947945B70>
# <Element 'Classinheritancerichness' at 0x0000022947944EF0>
# <Element 'Classreadability' at 0x0000022947947D30>
# <Element 'Classrelationshiprichness' at 0x0000022947945760>
# <Element 'Classchildrencount' at 0x0000022947944860>
# <Element 'Classinstancescount' at 0x0000022947946FC0>
# <Element 'Classpropertiescount' at 0x00000229479450D0>
# <Element 'Classconnectivity' at 0x0000022947947830>
# <Element 'Classfulness' at 0x0000022947946D90>
# <Element 'Classimportance' at 0x0000022947944B80>
# <Element 'Classinheritancerichness' at 0x0000022947944F90>
# <Element 'Classreadability' at 0x00000229479477E0>
# <Element 'Classrelationshiprichness' at 0x0000022947946C00>
# <Element 'Classchildrencount' at 0x0000022947947B00>
# <Element 'Classinstancescount' at 0x0000022947944F40>
# <Element 'Classpropertiescount' at 0x0000022947946A70>
# <Element 'Classconnectivity' at 0x0000022947946DE0>
# <Element 'Classfulness' at 0x0000022947947DD0>
# <Element 'Classimportance' at 0x0000022947947060>
# <Element 'Classinheritancerichness' at 0x0000022947945CB0>
# <Element 'Classreadability' at 0x0000022947946110>
# <Element 'Classrelationshiprichness' at 0x0000022947944770>
# <Element 'Classchildrencount' at 0x00000229479475B0>
# <Element 'Classinstancescount' at 0x000002294514E6B0>
# <Element 'Classpropertiescount' at 0x000002294514EF20>
# <Element 'Classconnectivity' at 0x000002294514FD80>
# <Element 'Classfulness' at 0x000002294514FBF0>
# <Element 'Classimportance' at 0x000002294514E020>
# <Element 'Classinheritancerichness' at 0x000002294514E750>
# <Element 'Classreadability' at 0x000002294514F290>
# <Element 'Classrelationshiprichness' at 0x0000022943DBF290>
# <Element 'Classchildrencount' at 0x0000022944DFA340>
# <Element 'Classinstancescount' at 0x0000022944DF8900>
# <Element 'Classpropertiescount' at 0x0000022944DF9350>
# <Element 'Classconnectivity' at 0x0000022944DFB010>
# <Element 'Classfulness' at 0x0000022944DF92B0>
# <Element 'Classimportance' at 0x0000022944DFB240>
# <Element 'Classinheritancerichness' at 0x0000022944DF9D50>
# <Element 'Classreadability' at 0x0000022944DFA6B0>
# <Element 'Classrelationshiprichness' at 0x0000022944DFAE80>
# <Element 'Classchildrencount' at 0x0000022944DF9800>
# <Element 'Classinstancescount' at 0x0000022944DFA5C0>
# <Element 'Classpropertiescount' at 0x0000022944DFA3E0>
# <Element 'Classconnectivity' at 0x0000022944DF9260>
# <Element 'Classfulness' at 0x0000022944DF8590>
# <Element 'Classimportance' at 0x0000022944DFA1B0>
# <Element 'Classinheritancerichness' at 0x0000022944DF9DF0>
# <Element 'Classreadability' at 0x0000022944DFB420>
# <Element 'Classrelationshiprichness' at 0x0000022944DFB7E0>
# <Element 'Classchildrencount' at 0x0000022944DFA9D0>
# <Element 'Classinstancescount' at 0x0000022944DF8C70>
# <Element 'Classpropertiescount' at 0x0000022944DFB560>
# <Element 'Classconnectivity' at 0x0000022944DFA570>
# <Element 'Classfulness' at 0x0000022944DFA110>
# <Element 'Classimportance' at 0x0000022944DFB880>
# <Element 'Classinheritancerichness' at 0x0000022944DFB650>
# <Element 'Classreadability' at 0x0000022944DFB3D0>
# <Element 'Classrelationshiprichness' at 0x0000022944DF8C20>
# <Element 'Classchildrencount' at 0x0000022944DF8D60>
# <Element 'Classinstancescount' at 0x0000022944DF9F80>
# <Element 'Classpropertiescount' at 0x0000022944DFAAC0>
# <Element 'Classconnectivity' at 0x0000022947EC2E80>
# <Element 'Classfulness' at 0x0000022947EC0CC0>
# <Element 'Classimportance' at 0x0000022947EC1350>
# <Element 'Classinheritancerichness' at 0x0000022947EC09F0>
# <Element 'Classreadability' at 0x0000022947EC3F60>
# <Element 'Classrelationshiprichness' at 0x0000022947EC25C0>
# <Element 'Classchildrencount' at 0x0000022947EC1210>
# <Element 'Classinstancescount' at 0x0000022947EC2160>
# <Element 'Classpropertiescount' at 0x0000022947EC1580>
# <Element 'Classconnectivity' at 0x0000022947EC3AB0>
# <Element 'Classfulness' at 0x0000022947EC1F80>
# <Element 'Classimportance' at 0x0000022947EC1C60>
# <Element 'Classinheritancerichness' at 0x0000022947EC0E50>
# <Element 'Classreadability' at 0x0000022947EC3B00>
# <Element 'Classrelationshiprichness' at 0x0000022947EC0680>
# <Element 'Classchildrencount' at 0x0000022947EC2110>
# <Element 'Classinstancescount' at 0x0000022947EC0D10>
# <Element 'Classpropertiescount' at 0x0000022947EC0AE0>
# <Element 'Classconnectivity' at 0x0000022947EC1EE0>
# <Element 'Classfulness' at 0x0000022947EC23E0>
# <Element 'Classimportance' at 0x0000022947EC1670>
# <Element 'Classinheritancerichness' at 0x0000022947EC2480>
# <Element 'Classreadability' at 0x0000022947EC0090>
# <Element 'Classrelationshiprichness' at 0x0000022947EC3F10>
# <Element 'Classchildrencount' at 0x0000022947EC1120>
# <Element 'Classinstancescount' at 0x0000022947EC1990>
# <Element 'Classpropertiescount' at 0x0000022947EC2070>
# <Element 'Classconnectivity' at 0x0000022947EC1440>
# <Element 'Classfulness' at 0x0000022947EC1800>
# <Element 'Classimportance' at 0x0000022947EC2430>
# <Element 'Classinheritancerichness' at 0x0000022947EC29D0>
# <Element 'Classreadability' at 0x0000022947EC3970>
# <Element 'Classrelationshiprichness' at 0x0000022947EC2DE0>
# <Element 'Classchildrencount' at 0x0000022947EC2C00>
# <Element 'Classinstancescount' at 0x0000022947EC1030>
# <Element 'Classpropertiescount' at 0x0000022947EC2CF0>
# <Element 'Classconnectivity' at 0x0000022947EC0EA0>
# <Element 'Classfulness' at 0x0000022947EC09A0>
# <Element 'Classimportance' at 0x0000022947EC05E0>
# <Element 'Classinheritancerichness' at 0x0000022947EC1D00>
# <Element 'Classreadability' at 0x0000022947EC1D50>
# <Element 'Classrelationshiprichness' at 0x0000022947EC11C0>
# <Element 'Classchildrencount' at 0x0000022947EC0540>
# <Element 'Classinstancescount' at 0x0000022947EC0630>
# <Element 'Classpropertiescount' at 0x0000022947EC2570>
# <Element 'Classconnectivity' at 0x0000022947EC2610>
# <Element 'Classfulness' at 0x0000022947EC16C0>
# <Element 'Classimportance' at 0x0000022947EC1E40>
# <Element 'Classinheritancerichness' at 0x0000022947EC02C0>
# <Element 'Classreadability' at 0x0000022947EC08B0>
# <Element 'Classrelationshiprichness' at 0x0000022947EC1B70>
# <Element 'Classchildrencount' at 0x0000022947EC0810>
# <Element 'Classinstancescount' at 0x0000022947EC1B20>
# <Element 'Classpropertiescount' at 0x0000022947EC0900>
# <Element 'Classconnectivity' at 0x0000022947EC26B0>
# <Element 'Classfulness' at 0x0000022947EC0A90>
# <Element 'Classimportance' at 0x0000022947EC27A0>
# <Element 'Classinheritancerichness' at 0x0000022947EC0EF0>
# <Element 'Classreadability' at 0x0000022947EC2BB0>
# <Element 'Classrelationshiprichness' at 0x0000022947EC2250>
# <Element 'Classchildrencount' at 0x0000022947EC24D0>
# <Element 'Classinstancescount' at 0x0000022947EC0310>
# <Element 'Classpropertiescount' at 0x0000022947EC2660>
# <Element 'Classconnectivity' at 0x0000022947EC1DA0>
# <Element 'Classfulness' at 0x0000022947EC0950>
# <Element 'Classimportance' at 0x0000022947EC04F0>
# <Element 'Classinheritancerichness' at 0x0000022947EC1300>
# <Element 'Classreadability' at 0x0000022947EC21B0>
# <Element 'Classrelationshiprichness' at 0x0000022947EC2AC0>
# <Element 'Classchildrencount' at 0x0000022947EC1C10>
# <Element 'Classinstancescount' at 0x0000022947EC2C50>
# <Element 'Classpropertiescount' at 0x0000022947EC2200>
# <Element 'Classconnectivity' at 0x0000022947EC1AD0>
# <Element 'Classfulness' at 0x0000022947EC0130>
# <Element 'Classimportance' at 0x0000022947EC2980>
# <Element 'Classinheritancerichness' at 0x0000022947EC1490>
# <Element 'Classreadability' at 0x0000022947EC2D90>
# <Element 'Classrelationshiprichness' at 0x0000022947EC0DB0>
# <Element 'Classchildrencount' at 0x0000022947EC27F0>
# <Element 'Classinstancescount' at 0x0000022947EC17B0>
# <Element 'Classpropertiescount' at 0x0000022947EC1E90>
# <Element 'Classconnectivity' at 0x0000022947EC34C0>
# <Element 'Classfulness' at 0x0000022947EC0D60>
# <Element 'Classimportance' at 0x0000022947EC0720>
# <Element 'Classinheritancerichness' at 0x0000022947EC1850>
# <Element 'Classreadability' at 0x0000022947EC2750>
# <Element 'Classrelationshiprichness' at 0x0000022947EC2520>
# <Element 'Classchildrencount' at 0x0000022947EC1260>
# <Element 'Classinstancescount' at 0x0000022947EC0F90>
# <Element 'Classpropertiescount' at 0x0000022947EC1760>
# <Element 'Classconnectivity' at 0x0000022947EC3FB0>
# <Element 'Classfulness' at 0x0000022947EC0BD0>
# <Element 'Classimportance' at 0x0000022947EC0590>
# <Element 'Classinheritancerichness' at 0x0000022947EC2840>
# <Element 'Classreadability' at 0x0000022947EC1CB0>
# <Element 'Classrelationshiprichness' at 0x0000022947EC2D40>
# <Element 'Classchildrencount' at 0x0000022947EC2890>
# <Element 'Classinstancescount' at 0x0000022947D388B0>
# <Element 'Classpropertiescount' at 0x0000022947D3BD30>
# <Element 'Classconnectivity' at 0x0000022947D3A390>
# <Element 'Classfulness' at 0x0000022947D3AB60>
# <Element 'Classimportance' at 0x0000022947D39080>
# <Element 'Classinheritancerichness' at 0x0000022947D3B790>
# <Element 'Classreadability' at 0x0000022947D3BBF0>
# <Element 'Classrelationshiprichness' at 0x0000022947D38D60>
# <Element 'Classchildrencount' at 0x0000022947D3A520>
# <Element 'Classinstancescount' at 0x0000022947D3B600>
# <Element 'Classpropertiescount' at 0x0000022947D3A0C0>
# <Element 'Classconnectivity' at 0x0000022947D3BDD0>
# <Element 'Classfulness' at 0x0000022947D38270>
# <Element 'Classimportance' at 0x0000022947D39A30>
# <Element 'Classinheritancerichness' at 0x0000022947D3AC50>
# <Element 'Classreadability' at 0x0000022947D38310>
# <Element 'Classrelationshiprichness' at 0x0000022947D3AA70>
# <Element 'Classchildrencount' at 0x0000022947D3BF10>
# <Element 'Classinstancescount' at 0x0000022947D39260>
# <Element 'Classpropertiescount' at 0x0000022947D39170>
# <Element 'Classconnectivity' at 0x0000022947D3AF20>
# <Element 'Classfulness' at 0x0000022947D396C0>
# <Element 'Classimportance' at 0x0000022947D39C10>
# <Element 'Classinheritancerichness' at 0x0000022947D39620>
# <Element 'Classreadability' at 0x0000022947D38CC0>
# <Element 'Classrelationshiprichness' at 0x0000022947D3A020>
# <Element 'Classchildrencount' at 0x0000022947D38220>
# <Element 'Classinstancescount' at 0x0000022947D38E00>
# <Element 'Classpropertiescount' at 0x0000022947D39EE0>
# <Element 'Classconnectivity' at 0x0000022947D384F0>
# <Element 'Classfulness' at 0x0000022947D38130>
# <Element 'Classimportance' at 0x0000022947D3BFB0>
# <Element 'Classinheritancerichness' at 0x0000022947D39DF0>
# <Element 'Classreadability' at 0x0000022947D398A0>
# <Element 'Classrelationshiprichness' at 0x0000022947D39F30>
# <Element 'Classchildrencount' at 0x0000022947D3B100>
# <Element 'Classinstancescount' at 0x0000022947D3B510>
# <Element 'Classpropertiescount' at 0x0000022947D39A80>
# <Element 'Classconnectivity' at 0x0000022947D39760>
# <Element 'Classfulness' at 0x0000022947D3B1A0>
# <Element 'Classimportance' at 0x0000022947D3BAB0>
# <Element 'Classinheritancerichness' at 0x0000022947D3B150>
# <Element 'Classreadability' at 0x0000022947D38DB0>
# <Element 'Classrelationshiprichness' at 0x0000022947D3B6A0>
# <Element 'Classchildrencount' at 0x0000022947D39490>
# <Element 'Classinstancescount' at 0x0000022947D3BD80>
# <Element 'Classpropertiescount' at 0x0000022947D3AE30>
# <Element 'Classconnectivity' at 0x0000022947D38A40>
# <Element 'Classfulness' at 0x0000022947D398F0>
# <Element 'Classimportance' at 0x0000022947D3A110>
# <Element 'Classinheritancerichness' at 0x0000022947D3BE70>
# <Element 'Classreadability' at 0x0000022947D393A0>
# <Element 'Classrelationshiprichness' at 0x0000022947D38F90>
# <Element 'Classchildrencount' at 0x0000022947D390D0>
# <Element 'Classinstancescount' at 0x0000022947D38860>
# <Element 'Classpropertiescount' at 0x0000022947D3B7E0>
# <Element 'Classconnectivity' at 0x0000022947D39AD0>
# <Element 'Classfulness' at 0x0000022947D38720>
# <Element 'Classimportance' at 0x0000022947D38360>
# <Element 'Classinheritancerichness' at 0x0000022947D38AE0>
# <Element 'Classreadability' at 0x0000022947D39580>
# <Element 'Classrelationshiprichness' at 0x0000022947D3BC90>
# <Element 'Classchildrencount' at 0x0000022947D3B4C0>
# <Element 'Classinstancescount' at 0x0000022947D39120>
# <Element 'Classpropertiescount' at 0x0000022947D38B80>
# 0 https://saref.etsi.org/core/TemperatureSensor

# %%
# Out:
# 0 https://saref.etsi.org/core/TemperatureSensor
# 0 https://saref.etsi.org/core/TemperatureSensor
# 1 https://saref.etsi.org/core/TemperatureSensor
# 81 https://saref.etsi.org/core/TemperatureSensor
# 2 https://saref.etsi.org/core/TemperatureSensor
# 0 https://saref.etsi.org/core/TemperatureSensor
# 19 https://saref.etsi.org/core/TemperatureSensor
# 10 https://saref.etsi.org/core/TemperatureSensor
# 0 https://saref.etsi.org/core/TemperatureSensor

# %%
max_values[0]
# Out:
# 0

# %%
df_metrics_table = add_metrics(df_metrics_table, df_)

    

df_metrics_table.drop(["metric_code"], axis=1, inplace=True)

df_metrics_table
# Out:
#                   metric_name                   ontometrics_name  \
# 0                    # axioms                             Axioms
# 1            # logical axioms                Logical Axiom count
# 2                   # classes                        Class count
# 3         # object properties            Object properties count
# 4       # datatype properties                Data property count
# 5     # annotation assertions  Annotation assertions axiom count
# 6             DL expressivity                    DL expressivity
# 7          Attribute Richness                 Attribute Richness
# 8        Inheritance Richness               Inheritance Richness
# 9       Relationship Richness              Relationship Richness
# 10          Axiom Class Ratio                  Axiom Class Ratio
# 11          Equivalence Ratio                  Equivalence Ratio
# 12        Class/propery ratio               Class Relation Ratio
# 13                        NoR          Absolute root cardinality
# 14                        NoL          Absolute leaf cardinality
# 15             Absolute depth                     Absolute depth
# 16                    ADIT-LN                      Average depth
# 17                  Max depth                      Maximal depth
# 18           Absolute breadth                   Absolute breadth
# 19            Average breadth                    Average breadth
# 20                Max breadth                    Maximal breadth
# 21                Tangledness                        Tangledness
# 22          Classconnectivity                  Classconnectivity
# 23               Classfulness                       Classfulness
# 24            Classimportance                    Classimportance
# 25   Classinheritancerichness           Classinheritancerichness
# 26           Classreadability                   Classreadability
# 27  Classrelationshiprichness          Classrelationshiprichness
# 28         Classchildrencount                 Classchildrencount
# 29        Classinstancescount                Classinstancescount
# 30       Classpropertiescount               Classpropertiescount
#
#                                   evaluation_criteria     SAREF
# 0                                                None       631
# 1                                                None       226
# 2                                                None        81
# 3                                                None        35
# 4                                                None         5
# 5                                                None       264
# 6                                                None  ALCIQ(D)
# 7                                                 NaN  0.061728
# 8          low => vertical&#10;high => orizontal&#10;  1.814815
# 9   low => less information&#10;High => more infor...  0.209677
# 10  low (near 0) => poor axiomatisation&#10;Higher...  7.790123
# 11                                                NaN       0.0
# 12  Low values (i.e near 0) indicate an ontology w...  0.435484
# 13  The interpretation of NoR values depends on th...         5
# 14  The interpretation of NoL values depends on th...        19
# 15                                                NaN        51
# 16  The interpretation of the values depends on th...      2.04
# 17  The interpretation of max depth is similar to ...         3
# 18                                                NaN        25
# 19  The value should be interpreted relatively to ...  3.571429
# 20  The value should be interpreted relatively to ...         6
# 21  Values for tangledness range from 0 (i.e. no t...       0.0
# 22                                                NaN       NaN
# 23                                                NaN       NaN
# 24                                                NaN       NaN
# 25                                                NaN       NaN
# 26                                                NaN       NaN
# 27                                                NaN       NaN
# 28                                                NaN       NaN
# 29                                                NaN       NaN
# 30                                                NaN       NaN
