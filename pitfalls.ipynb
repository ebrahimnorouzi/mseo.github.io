# %%
# Import necessary libraries
import pandas as pd
from IPython.display import display, HTML
import re

# Define the LaTeX file path
latex_file = 'pitfalls.tex'

# Read the LaTeX file
with open(latex_file, 'r') as file:
    latex_content = file.read()

# Extract the table content from the LaTeX file
start_marker = '\\begin{tabular}'
end_marker = '\\end{tabular}'

start_idx = latex_content.find(start_marker)
end_idx = latex_content.find(end_marker) + len(end_marker)

if start_idx != -1 and end_idx != -1:
    table_content = latex_content[start_idx:end_idx]
else:
    table_content = "Table not found in the LaTeX file."

# Parse the table content
table_rows = table_content.split('\\\\')
parsed_data = []
for row in table_rows:
    # Remove LaTeX commands and trim whitespace
    cleaned_row = re.sub(r'\\[a-zA-Z]+', '', row).strip()
    if cleaned_row:
        parsed_data.append([cell.strip() for cell in cleaned_row.split('&')])

# Create a pandas DataFrame
columns = parsed_data[1]
data = parsed_data[2:-1]
df = pd.DataFrame(data, columns=columns)

# Display the DataFrame as an HTML table
display(HTML(df.to_html(index=False, escape=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Ontology Name</th>
#       <th>Critical</th>
#       <th>Important</th>
#       <th>Minor</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>AMONTOLOGY</td>
#       <td>P19: 9</td>
#       <td>P11: 2, P24: 1, P34: 60</td>
#       <td>P04: 2, P08: 305, P13: 9</td>
#     </tr>
#     <tr>
#       <td>BWMD-DOMAIN</td>
#       <td>P19: 1</td>
#       <td>P11: 30, P30: 13</td>
#       <td>P04: 1, P08: 37, P13: 24, P32: 11, P36: 1</td>
#     </tr>
#     <tr>
#       <td>BWMD-MID</td>
#       <td>P19: 1</td>
#       <td>P11: 30, P30: 12</td>
#       <td>P04: 1, P08: 37, P13: 24, P36: 1</td>
#     </tr>
#     <tr>
#       <td>CHAMEO</td>
#       <td>-</td>
#       <td>-</td>
#       <td>P36: 1</td>
#     </tr>
#     <tr>
#       <td>CIF-core</td>
#       <td>-</td>
#       <td>P11: 5, P30: 1</td>
#       <td>P04: 20, P08: 72, P13: 4, P22: 1, P36: 1</td>
#     </tr>
#     <tr>
#       <td>DEB</td>
#       <td>P19: 89, P27: 1, P31: 3</td>
#       <td>P11: 11, P30: 8</td>
#       <td>P02: 8, P04: 1, P08: 711, P13: 12, P21: 1, P22: 1, P36: 1</td>
#     </tr>
#     <tr>
#       <td>DISO</td>
#       <td>P40: 2</td>
#       <td>P11: 15</td>
#       <td>P04: 1, P08: 20, P13: 31, P22: 1, P36: 1</td>
#     </tr>
#     <tr>
#       <td>EMMO</td>
#       <td>P19: 2</td>
#       <td>P11: 72, P24: 8, P25: 7, P26: 7, P34: 56</td>
#       <td>P04: 1, P08: 1306, P13: 76, P22: 1, P36: 1</td>
#     </tr>
#     <tr>
#       <td>EMMO_BVC</td>
#       <td>-</td>
#       <td>-</td>
#       <td>P36: 1</td>
#     </tr>
#     <tr>
#       <td>EMMO_BattINFO</td>
#       <td>-</td>
#       <td>-</td>
#       <td>P36: 1</td>
#     </tr>
#     <tr>
#       <td>EMMO_Datamodel</td>
#       <td>P37: 1</td>
#       <td>-</td>
#       <td>P36: 1</td>
#     </tr>
#     <tr>
#       <td>EMMO_atomistic</td>
#       <td>-</td>
#       <td>P11: 25, P24: 12, P25: 7, P26: 7, P34: 48</td>
#       <td>P02: 1, P08: 578, P13: 32, P22: 1, P36: 1</td>
#     </tr>
#     <tr>
#       <td>EMMO_crystallography</td>
#       <td>-</td>
#       <td>P11: 32, P24: 12, P25: 7, P26: 7, P34: 57</td>
#       <td>P02: 1, P07: 4, P08: 1858, P13: 33, P22: 1, P36: 1</td>
#     </tr>
#     <tr>
#       <td>EMMO_mappings</td>
#       <td>-</td>
#       <td>P11: 25, P24: 12, P25: 7, P26: 7, P34: 48</td>
#       <td>P02: 1, P08: 577, P13: 34, P22: 1, P36: 1</td>
#     </tr>
#     <tr>
#       <td>EMMO_mechanical_testing</td>
#       <td>P40: 4</td>
#       <td>-</td>
#       <td>P36: 1</td>
#     </tr>
#     <tr>
#       <td>EMMO_microstructure</td>
#       <td>P19: 2</td>
#       <td>P11: 71, P24: 1, P34: 73, P35: 1</td>
#       <td>P04: 119, P08: 1419, P13: 76, P22: 1, P36: 1</td>
#     </tr>
#     <tr>
#       <td>GPO</td>
#       <td>P05: 1, P19: 3</td>
#       <td>P11: 42, P24: 14, P25: 8, P26: 10, P34: 46</td>
#       <td>P02: 1, P08: 1047, P13: 61, P22: 1, P36: 1</td>
#     </tr>
#     <tr>
#       <td>LPBFO</td>
#       <td>P19: 1</td>
#       <td>P11: 31, P30: 13</td>
#       <td>P02: 1, P04: 1, P08: 46, P13: 25, P32: 4, P36: 1</td>
#     </tr>
#     <tr>
#       <td>MAMBO</td>
#       <td>P19: 2, P29: 3, P40: 1</td>
#       <td>P11: 7, P30: 1, P38: 1</td>
#       <td>P04: 5, P08: 153, P13: 26, P22: 1, P36: 1</td>
#     </tr>
#     <tr>
#       <td>MDO</td>
#       <td>-</td>
#       <td>P11: 8</td>
#       <td>P04: 2, P08: 15, P13: 32, P22: 1, P36: 1</td>
#     </tr>
#     <tr>
#       <td>MOL_BRINELL</td>
#       <td>-</td>
#       <td>P11: 21</td>
#       <td>P04: 23, P08: 58, P13: 17, P22: 1, P36: 1</td>
#     </tr>
#     <tr>
#       <td>MOL_TENSILE</td>
#       <td>P19: 1</td>
#       <td>P11: 91, P30: 13</td>
#       <td>P04: 1, P08: 116, P13: 81, P20: 1</td>
#     </tr>
#     <tr>
#       <td>MSEO</td>
#       <td>P40: 1</td>
#       <td>-</td>
#       <td>P36: 1</td>
#     </tr>
#     <tr>
#       <td>MatOnto</td>
#       <td>P31: 5</td>
#       <td>P11: 27, P24: 6, P25: 6, P26: 5, P30: 11</td>
#       <td>P02: 9, P08: 371, P13: 17, P20: 2, P22: 1, P36: 1</td>
#     </tr>
#     <tr>
#       <td>NPO</td>
#       <td>-</td>
#       <td>P11: 77, P24: 2, P30: 1</td>
#       <td>P04: 4, P08: 1850, P13: 62, P20: 3, P22: 1, P36: 1</td>
#     </tr>
#     <tr>
#       <td>NanoMine</td>
#       <td>-</td>
#       <td>-</td>
#       <td>P36: 1</td>
#     </tr>
#     <tr>
#       <td>OEO</td>
#       <td>-</td>
#       <td>P11: 50, P30: 2</td>
#       <td>P04: 1, P08: 1511, P13: 88, P22: 1, P32: 1</td>
#     </tr>
#     <tr>
#       <td>PMDCO</td>
#       <td>P19: 2</td>
#       <td>P11: 25, P12: 1, P24: 1, P25: 1, P30: 2, P34: 9, P35: 37</td>
#       <td>P04: 1, P08: 44, P13: 9, P22: 1, P32: 2, P36: 1</td>
#     </tr>
#     <tr>
#       <td>SAREF</td>
#       <td>-</td>
#       <td>P11: 12, P24: 2, P30: 1</td>
#       <td>P13: 22, P36: 1</td>
#     </tr>
#     <tr>
#       <td>SEMMD</td>
#       <td>P40: 9</td>
#       <td>-</td>
#       <td>P36: 1</td>
#     </tr>
#     <tr>
#       <td>SP</td>
#       <td>P19: 3</td>
#       <td>P11: 21, P30: 3</td>
#       <td>P04: 1, P07: 5, P08: 249, P13: 39, P22: 1, P32: 7, P36: 1</td>
#     </tr>
#     <tr>
#       <td>SSN</td>
#       <td>-</td>
#       <td>P11: 23, P30: 1, P38: 1</td>
#       <td>P04: 16, P08: 3, P13: 3, P36: 1</td>
#     </tr>
#     <tr>
#       <td>bmo</td>
#       <td>P05: 1, P19: 1</td>
#       <td>P11: 34, P12: 4, P24: 2, P30: 2, P34: 7</td>
#       <td>P04: 15, P07: 1, P08: 248, P13: 96, P20: 1, P22: 1, P36: 1</td>
#     </tr>
#     <tr>
#       <td>enanomapper</td>
#       <td>-</td>
#       <td>-</td>
#       <td>P36: 1</td>
#     </tr>
#     <tr>
#       <td>mat</td>
#       <td>-</td>
#       <td>P11: 21</td>
#       <td>P07: 16, P08: 128, P13: 13, P36: 1</td>
#     </tr>
#     <tr>
#       <td>matinfo</td>
#       <td>-</td>
#       <td>P11: 58, P12: 3, P30: 15</td>
#       <td>P04: 1, P07: 2, P08: 703, P13: 31, P21: 1, P22: 1, P36: 1</td>
#     </tr>
#     <tr>
#       <td>mvc</td>
#       <td>P19: 3, P31: 2, P40: 1</td>
#       <td>P11: 1, P34: 14, P35: 1</td>
#       <td>P04: 1, P08: 12, P13: 8, P22: 1, P36: 1</td>
#     </tr>
#     <tr>
#       <td>mwo</td>
#       <td>P05: 1, P31: 1</td>
#       <td>P11: 46, P12: 1, P24: 1, P30: 1, P34: 1</td>
#       <td>P02: 1, P04: 4, P08: 125, P13: 28, P20: 7, P22: 1</td>
#     </tr>
#     <tr>
#       <td>periodictable</td>
#       <td>-</td>
#       <td>P11: 13</td>
#       <td>P08: 19, P13: 6, P36: 1</td>
#     </tr>
#     <tr>
#       <td>ssos</td>
#       <td>P19: 1</td>
#       <td>P11: 34</td>
#       <td>P04: 4, P07: 2, P08: 65, P13: 16, P22: 1</td>
#     </tr>
#     <tr>
#       <td>vimmp</td>
#       <td>P19: 5, P29: 2</td>
#       <td>P34: 20, P35: 30</td>
#       <td>P08: 318, P13: 119, P36: 1</td>
#     </tr>
#   </tbody>
# </table>
